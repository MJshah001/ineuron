# %% [markdown]
# # data visualization

# %% [markdown]
# ## In this assignment students have to transform iris data into 3 dimensions and plot a 3d chart with transformed dimensions and colour each data point with specific class.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn import decomposition
from sklearn import datasets
# %matplotlib inline

# %%
iris = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data",names=['sepal length','sepal width','petal length','petal width','target'])
iris.head()
# Out:
#    sepal length  sepal width  petal length  petal width       target
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
x = iris.drop('target',axis=1)
y = iris['target']

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=3)
x_reduced = pca.fit_transform(x)

# %%
print(x.shape)
print(x_reduced.shape)
# Out:
# (150, 4)
# (150, 3)

# %%
Y = y.map({'Iris-virginica': 0, 'Iris-versicolor': 1 , 'Iris-setosa' : 2})
Y
# Out:
# 0      2
# 1      2
# 2      2
# 3      2
# 4      2
#       ..
# 145    0
# 146    0
# 147    0
# 148    0
# 149    0
# Name: target, Length: 150, dtype: int64

# %%
fig = plt.figure(1,figsize=(8,6))
axes = fig.add_subplot(111,projection='3d')
axes.scatter(x_reduced[:,0],x_reduced[:,1],x_reduced[:,2],c=Y)
