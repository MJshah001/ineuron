# %% [markdown]
# # Numpy assignment

# %% [markdown]
# ## Write a function so that the columns of the output matrix are powers of the input vector.
# ## The order of the powers is determined by the increasing boolean argument. Specifically, when increasing is False, the i-th output column is the input vector raised element-wise to the power of N - i - 1.
# ## HINT: Such a matrix with a geometric progression in each row is named for Alexandre- Theophile Vandermonde.

# %%
import numpy as np

# %%
def Vandermonde(inputvector, N ,increasing) :
    if increasing == True :
        return np.matrix([x**i for x in inputvector for i in range(N)]).reshape(inputvector.size,N)
    else :
        return np.matrix([x**(N-i-1) for x in inputvector for i in range(N)]).reshape(inputvector.size,N)

# %%
Vandermonde(np.array([1,2,3,6,9]),5,True)
# Out:
# matrix([[   1,    1,    1,    1,    1],
#         [   1,    2,    4,    8,   16],
#         [   1,    3,    9,   27,   81],
#         [   1,    6,   36,  216, 1296],
#         [   1,    9,   81,  729, 6561]])

# %%
Vandermonde(np.array([1,2,3,6,9]),5,False)
# Out:
# matrix([[   1,    1,    1,    1,    1],
#         [  16,    8,    4,    2,    1],
#         [  81,   27,    9,    3,    1],
#         [1296,  216,   36,    6,    1],
#         [6561,  729,   81,    9,    1]])

# %% [markdown]
# ## Question: Write a function to find moving average in an array over a window:
# ### Test it over [3, 5, 7, 2, 8, 10, 11, 65, 72, 81, 99, 100, 150] and window of 3.

# %%
def moving_avg(vals,k) :
    for i in range(0,len(vals)-k):
        x=0
        for j in range(i,i+k):
            x = x + vals[j]
        print("y_{} : {}".format(i,x/k))

# %%
vals = [3, 5, 7, 2, 8, 10, 11, 65, 72, 81, 99, 100, 150]
k = 3

moving_avg(vals,k)
# Out:
# y_0 : 5.0
# y_1 : 4.666666666666667
# y_2 : 5.666666666666667
# y_3 : 6.666666666666667
# y_4 : 9.666666666666666
# y_5 : 28.666666666666668
# y_6 : 49.333333333333336
# y_7 : 72.66666666666667
# y_8 : 84.0
# y_9 : 93.33333333333333
